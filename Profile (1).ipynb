# %% [markdown]
# <h1>Модуль profile и cProfile</h1>
#
# Стандартные библиотеки Python поражают своим разнообразием. В них, кажется, есть всё, что только может понадобится разработчику, и профайлеры не исключение. На самом деле их целых три «из коробки»:
#
# cProfile — относительно новый (с версии 2.5) модуль, написанный на C и оттого быстрый
#
# profile — нативная реализация профайлера (написан на чистом питоне), медленный, и поэтому не рекомендуется к использованию
#
# hotshot — экспериментальный модуль на си, очень быстрый, но больше не поддерживается и в любой момент может быть удалён из стандартных библиотек

# %% [markdown]
# Профилирование — сбор статистики во время работы программы. В дальнейшем будет рассмотрено использование памяти и измерение
# времени работы.

# %% [markdown]
# Данные полученные в результате профилирования могут быть отформатированы в отчеты через модуль pstats - его более подробно рассмотрим позже.

# %% [markdown]
# cProfile - это детерминированный профилировщик: в нем отслеживаются вызов функции, возврат функции и события исключения, а также точные тайминги для интервалов между этими событиями (до 0,001 с). Документация библиотеки ([ https://docs.python.org/2/library/profile.html][1]) предоставляет нам простой пример использования

# %%
import hashlib
import cProfile
 
cProfile.run("hashlib.md5(b'abcdefghijkl').digest()")
# Out:
#          5 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# Здесь мы импортировали модуль hashlib и использовали cProfile для профилирования того, что создал хеш MD5. Первая строка показывает, что в ней 4 вызова функций. Следующая строка говорит нам, в каком порядке результаты выдачи. Но что же означают эти столбцы?
#
# ncalls – это количество совершенных вызовов;
#
# tottime – это все время, потраченное в данной функции;
#
# percall – ссылается на коэффициент tottime, деленный на ncalls;
#
# cumtime – совокупное время, потраченное как в данной функции, так и наследуемых функциях. Это работает также и с рекурсивными функциями!
#
# Второй столбец percall – это коэффициент cumtime деленный на примитивные вызовы;
#
# filename:lineno(function) предоставляет соответствующие данные о каждой функции.

# %% [markdown]
# Есть такое понятие - Примитивный вызов. Это вызов, который не был совершен при помощи рекурсии. Это очень интересный пример, так как здесь нет очевидных узких мест. Давайте создадим часть кода с узкими местами, и посмотрим, обнаружит ли их профайлер.

# %%
# -*- coding: utf-8 -*-
import time
import cProfile

def fast():
    print("Я быстрая функция")
 
 
def slow():
    time.sleep(3)
    print("Я очень медленная функция")
 
 
def medium():
    time.sleep(0.5)
    print("Я средняя функция...")
 
 
def main():
    fast()
    slow()
    medium()
 
if __name__ == '__main__':
    main()
    
    
cProfile.run('main()')
# Out:
# Я быстрая функция
# Я очень медленная функция
# Я средняя функция...
# Я быстрая функция
# Я очень медленная функция
# Я средняя функция...
#          106 function calls in 3.503 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.501    0.501 <ipython-input-2-25ee32f7a195>:14(medium)
#         1    0.000    0.000    3.503    3.503 <ipython-input-2-25ee32f7a195>:19(main)
#         1    0.000    0.000    0.001    0.001 <ipython-input-2-25ee32f7a195>:5(fast)
#         1    0.000    0.000    3.001    3.001 <ipython-input-2-25ee32f7a195>:9(slow)
#         1    0.001    0.001    3.503    3.503 <string>:1(<module>)
#         8    0.000    0.000    0.003    0.000 iostream.py:197(schedule)
#         6    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         6    0.000    0.000    0.001    0.000 iostream.py:323(_schedule_flush)
#         6    0.000    0.000    0.003    0.000 iostream.py:386(write)
#         8    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         8    0.002    0.000    0.002    0.000 socket.py:357(send)
#         8    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         8    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         8    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         1    0.000    0.000    3.503    3.503 {built-in method builtins.exec}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.003    0.001 {built-in method builtins.print}
#         6    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    3.500    1.750    3.500    1.750 {built-in method time.sleep}
#         8    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# На этот раз мы видим, что у программы ушло 3.5 секунды на запуск. Если вы изучите результаты, то увидите, что cProfile выявил медленную функцию, которая тратит 3 секунды на запуск. Это и есть самая «слабая» часть основной функции. Обычно, когда вы обнаруживаете такие места, вы можете попытаться найти самый быстрый способ выполнения вашего кода, или прийти к выводу, что такая задержка приемлема. В этом примере, мы знаем, что лучший способ ускорить функцию, то убрать вызов time.sleep, или, по крайней мере, снизить продолжительность сна. Вы можете также вызвать cProfile в командной строке, вместо применения в интерпретаторе. Как это сделать:

# %%
python -m cProfile ptest.py
# Out:
#   File "<ipython-input-9-472722e8767a>", line 1
#     python -m cProfile ptest.py
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h1>Выясняем скорость загрузки сайтов</h1>
# Давайте немного развлечемся. С помощью модуля cProfile мы можем узнавать не только время выполнения команд в программе, но и время работы других запросов.
# Сделаем небольшой марафон и узнаем какой сайт быстрее всех откроется из нашей программы.

# %%
# -*- coding: utf-8 -*-
import requests
import cProfile
 
 
def facebook():
    requests.get('https://facebook.com')
 
 
def google():
    requests.get('https://google.com')
	
	
def twitter():
    requests.get('https://twitter.com')
	
	
def vk():
    requests.get('https://vk.com')
 
 
def main():
    facebook()
    google()
    twitter()
    vk()
	
	
cProfile.run('main()')
# Out:
#          40197 function calls (40168 primitive calls) in 2.026 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.444    0.444 <ipython-input-12-fec7e32c8065>:10(google)
#         1    0.000    0.000    0.519    0.519 <ipython-input-12-fec7e32c8065>:14(twitter)
#         1    0.000    0.000    0.426    0.426 <ipython-input-12-fec7e32c8065>:18(vk)
#         1    0.000    0.000    2.027    2.027 <ipython-input-12-fec7e32c8065>:22(main)
#         1    0.000    0.000    0.638    0.638 <ipython-input-12-fec7e32c8065>:6(facebook)
#         1    0.000    0.000    2.027    2.027 <string>:1(<module>)
#         7    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        14    0.000    0.000    0.000    0.000 __init__.py:1412(debug)
#        14    0.000    0.000    0.000    0.000 __init__.py:1677(isEnabledFor)
#         7    0.000    0.000    0.002    0.000 _collections.py:140(__init__)
#       118    0.001    0.000    0.001    0.000 _collections.py:155(__getitem__)
#        97    0.000    0.000    0.000    0.000 _collections.py:186(__iter__)
#       100    0.001    0.000    0.001    0.000 _collections.py:214(add)
#         7    0.000    0.000    0.001    0.000 _collections.py:230(extend)
#         8    0.000    0.000    0.000    0.000 _collections.py:46(__init__)
#         7    0.000    0.000    0.000    0.000 _collections.py:53(__getitem__)
#         7    0.000    0.000    0.000    0.000 _collections.py:60(__setitem__)
#         8    0.000    0.000    0.020    0.002 _collections.py:91(clear)
#       183    0.001    0.000    0.003    0.000 _collections_abc.py:657(get)
#        48    0.000    0.000    0.001    0.000 _collections_abc.py:664(__contains__)
#        53    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#        53    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         8    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#      1830    0.009    0.000    0.037    0.000 _collections_abc.py:742(__iter__)
#        12    0.000    0.000    0.000    0.000 _collections_abc.py:790(pop)
#        33    0.001    0.000    0.003    0.000 _collections_abc.py:824(update)
#        26    0.000    0.000    0.000    0.000 _internal_utils.py:14(to_native_string)
#         4    0.000    0.000    0.000    0.000 _internal_utils.py:30(unicode_is_ascii)
#       185    0.001    0.000    0.002    0.000 _policybase.py:281(_sanitize_header)
#       100    0.001    0.000    0.002    0.000 _policybase.py:293(header_source_parse)
#       185    0.001    0.000    0.003    0.000 _policybase.py:311(header_fetch_parse)
#       121    0.000    0.000    0.001    0.000 abc.py:96(__instancecheck__)
#         8    0.000    0.000    0.001    0.000 adapters.py:113(__init__)
#         8    0.000    0.000    0.000    0.000 adapters.py:146(init_poolmanager)
#         7    0.000    0.000    0.002    0.000 adapters.py:203(cert_verify)
#         7    0.000    0.000    0.017    0.002 adapters.py:255(build_response)
#         7    0.000    0.000    0.011    0.002 adapters.py:292(get_connection)
#         8    0.000    0.000    0.020    0.002 adapters.py:319(close)
#         7    0.000    0.000    0.001    0.000 adapters.py:329(request_url)
#         7    0.000    0.000    0.000    0.000 adapters.py:358(add_headers)
#         7    0.000    0.000    1.766    0.252 adapters.py:394(send)
#         8    0.000    0.000    0.000    0.000 adapters.py:58(__init__)
#         4    0.000    0.000    2.026    0.507 api.py:16(request)
#         4    0.000    0.000    2.026    0.507 api.py:64(get)
#        43    0.000    0.000    0.000    0.000 calendar.py:655(timegm)
#         7    0.000    0.000    0.001    0.000 client.py:1001(_send_output)
#         7    0.000    0.000    0.001    0.000 client.py:1055(putrequest)
#         7    0.000    0.000    0.000    0.000 client.py:1182(_encode_request)
#         7    0.000    0.000    0.000    0.000 client.py:1186(_validate_method)
#         7    0.000    0.000    0.000    0.000 client.py:1195(_validate_path)
#         7    0.000    0.000    0.000    0.000 client.py:1203(_validate_host)
#        36    0.001    0.000    0.002    0.000 client.py:1211(putheader)
#         7    0.000    0.000    0.001    0.000 client.py:1239(endheaders)
#         7    0.000    0.000    0.005    0.001 client.py:1252(request)
#         7    0.001    0.000    0.005    0.001 client.py:1257(_send_request)
#        36    0.000    0.000    0.000    0.000 client.py:1259(<genexpr>)
#         7    0.000    0.000    0.786    0.112 client.py:1303(getresponse)
#         7    0.001    0.000    0.011    0.002 client.py:204(parse_headers)
#         7    0.000    0.000    0.000    0.000 client.py:237(__init__)
#         7    0.000    0.000    0.773    0.110 client.py:267(_read_status)
#         7    0.000    0.000    0.786    0.112 client.py:300(begin)
#         7    0.000    0.000    0.000    0.000 client.py:380(_check_close)
#         7    0.000    0.000    0.000    0.000 client.py:409(_close_conn)
#        11    0.000    0.000    0.000    0.000 client.py:414(close)
#         7    0.000    0.000    0.000    0.000 client.py:426(flush)
#        22    0.000    0.000    0.000    0.000 client.py:437(isclosed)
#         4    0.000    0.000    0.000    0.000 client.py:447(read)
#         4    0.000    0.000    0.000    0.000 client.py:479(readinto)
#        90    0.000    0.000    0.079    0.001 client.py:605(_safe_read)
#         7    0.000    0.000    0.000    0.000 client.py:787(_get_content_length)
#         7    0.000    0.000    0.000    0.000 client.py:819(__init__)
#         7    0.000    0.000    0.000    0.000 client.py:865(_get_hostport)
#         7    0.000    0.000    0.002    0.000 client.py:928(close)
#         7    0.000    0.000    0.001    0.000 client.py:942(send)
#        43    0.000    0.000    0.000    0.000 client.py:980(_output)
#         7    0.000    0.000    0.000    0.000 connection.py:104(__init__)
#        21    0.000    0.000    0.000    0.000 connection.py:117(host)
#         7    0.000    0.000    0.000    0.000 connection.py:136(host)
#         7    0.000    0.000    0.313    0.045 connection.py:146(_new_conn)
#         7    0.000    0.000    0.001    0.000 connection.py:190(putrequest)
#         7    0.000    0.000    0.000    0.000 connection.py:248(__init__)
#         7    0.000    0.000    0.000    0.000 connection.py:274(set_cert)
#         7    0.001    0.000    0.933    0.133 connection.py:307(connect)
#         7    0.000    0.000    0.313    0.045 connection.py:33(create_connection)
#         7    0.000    0.000    0.002    0.000 connection.py:405(_match_hostname)
#         7    0.000    0.000    0.000    0.000 connection.py:89(_set_socket_options)
#         7    0.000    0.000    0.000    0.000 connection.py:97(allowed_gai_family)
#         7    0.000    0.000    0.001    0.000 connectionpool.py:1020(_normalize_host)
#         7    0.000    0.000    0.005    0.001 connectionpool.py:172(__init__)
#         7    0.000    0.000    0.001    0.000 connectionpool.py:242(_get_conn)
#         7    0.000    0.000    0.000    0.000 connectionpool.py:281(_put_conn)
#         7    0.000    0.000    0.000    0.000 connectionpool.py:309(_validate_conn)
#        14    0.000    0.000    0.000    0.000 connectionpool.py:319(_get_timeout)
#         7    0.000    0.000    1.726    0.247 connectionpool.py:356(_make_request)
#         7    0.014    0.002    0.019    0.003 connectionpool.py:460(close)
#         7    0.000    0.000    1.733    0.248 connectionpool.py:499(urlopen)
#         7    0.000    0.000    0.001    0.000 connectionpool.py:78(__init__)
#         7    0.000    0.000    0.005    0.001 connectionpool.py:857(__init__)
#         7    0.000    0.000    0.000    0.000 connectionpool.py:906(_prepare_conn)
#         7    0.000    0.000    0.001    0.000 connectionpool.py:934(_new_conn)
#         7    0.000    0.000    0.933    0.133 connectionpool.py:970(_validate_conn)
#        17    0.000    0.000    0.000    0.000 contextlib.py:108(__enter__)
#        17    0.000    0.000    0.001    0.000 contextlib.py:117(__exit__)
#        17    0.000    0.000    0.000    0.000 contextlib.py:238(helper)
#        17    0.000    0.000    0.000    0.000 contextlib.py:82(__init__)
#        34    0.001    0.000    0.003    0.000 cookiejar.py:1008(set_ok_domain)
#        34    0.000    0.000    0.000    0.000 cookiejar.py:1067(set_ok_port)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1088(return_ok)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1106(return_ok_version)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1115(return_ok_verifiability)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1127(return_ok_secure)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1133(return_ok_expires)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1139(return_ok_port)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1153(return_ok_domain)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1180(domain_return_ok)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1206(path_return_ok)
#        40    0.000    0.000    0.000    0.000 cookiejar.py:1219(vals_sorted_by_key)
#     46/38    0.000    0.000    0.001    0.000 cookiejar.py:1223(deepvalues)
#        22    0.000    0.000    0.001    0.000 cookiejar.py:1258(__init__)
#         3    0.000    0.000    0.000    0.000 cookiejar.py:1266(set_policy)
#         1    0.000    0.000    0.001    0.001 cookiejar.py:1269(_cookies_for_domain)
#         7    0.000    0.000    0.001    0.000 cookiejar.py:1287(_cookies_for_request)
#        12    0.000    0.000    0.000    0.000 cookiejar.py:129(offset_from_tz_string)
#         7    0.000    0.000    0.000    0.000 cookiejar.py:1294(_cookie_attrs)
#         1    0.000    0.000    0.000    0.000 cookiejar.py:1304(<lambda>)
#         7    0.000    0.000    0.001    0.000 cookiejar.py:1353(add_cookie_header)
#        28    0.001    0.000    0.002    0.000 cookiejar.py:1386(_normalized_cookie_tuples)
#        12    0.000    0.000    0.001    0.000 cookiejar.py:143(_str2time)
#        43    0.001    0.000    0.005    0.000 cookiejar.py:1483(_cookie_from_cookie_tuple)
#        28    0.001    0.000    0.007    0.000 cookiejar.py:1575(_cookies_from_attrs_set)
#        14    0.000    0.000    0.000    0.000 cookiejar.py:1584(_process_rfc2109_cookies)
#        20    0.001    0.000    0.018    0.001 cookiejar.py:1596(make_cookies)
#        35    0.000    0.000    0.000    0.000 cookiejar.py:1664(set_cookie)
#        20    0.001    0.000    0.035    0.002 cookiejar.py:1677(extract_cookies)
#         9    0.000    0.000    0.000    0.000 cookiejar.py:1689(clear)
#         7    0.000    0.000    0.000    0.000 cookiejar.py:1731(clear_expired_cookies)
#        36    0.000    0.000    0.000    0.000 cookiejar.py:1750(__iter__)
#        43    0.001    0.000    0.002    0.000 cookiejar.py:225(http2time)
#        14    0.000    0.000    0.000    0.000 cookiejar.py:341(split_header_words)
#       108    0.000    0.000    0.000    0.000 cookiejar.py:44(_debug)
#        43    0.000    0.000    0.000    0.000 cookiejar.py:452(strip_quotes)
#        14    0.003    0.000    0.008    0.001 cookiejar.py:459(parse_ns_headers)
#        91    0.000    0.000    0.001    0.000 cookiejar.py:528(is_HDN)
#        35    0.000    0.000    0.001    0.000 cookiejar.py:543(domain_match)
#        71    0.001    0.000    0.005    0.000 cookiejar.py:613(request_host)
#        36    0.000    0.000    0.003    0.000 cookiejar.py:629(eff_request_host)
#        35    0.000    0.000    0.003    0.000 cookiejar.py:640(request_path)
#        78    0.000    0.000    0.003    0.000 cookiejar.py:670(escape_path)
#        35    0.000    0.000    0.001    0.000 cookiejar.py:684(reach)
#        35    0.000    0.000    0.007    0.000 cookiejar.py:719(is_third_party)
#        43    0.000    0.000    0.001    0.000 cookiejar.py:73(_timegm)
#        34    0.000    0.000    0.001    0.000 cookiejar.py:754(__init__)
#         2    0.000    0.000    0.000    0.000 cookiejar.py:803(is_expired)
#        22    0.000    0.000    0.000    0.000 cookiejar.py:877(__init__)
#        35    0.000    0.000    0.000    0.000 cookiejar.py:919(is_blocked)
#        35    0.000    0.000    0.000    0.000 cookiejar.py:934(is_not_allowed)
#        34    0.001    0.000    0.015    0.000 cookiejar.py:942(set_ok)
#        34    0.000    0.000    0.000    0.000 cookiejar.py:961(set_ok_version)
#        34    0.000    0.000    0.007    0.000 cookiejar.py:976(set_ok_verifiability)
#        34    0.000    0.000    0.000    0.000 cookiejar.py:988(set_ok_name)
#        34    0.000    0.000    0.003    0.000 cookiejar.py:997(set_ok_path)
#        20    0.000    0.000    0.000    0.000 cookies.py:104(__init__)
#        40    0.000    0.000    0.000    0.000 cookies.py:111(info)
#        20    0.000    0.000    0.036    0.002 cookies.py:118(extract_cookies_to_jar)
#         7    0.000    0.000    0.002    0.000 cookies.py:135(get_cookie_header)
#        35    0.000    0.000    0.001    0.000 cookies.py:343(set_cookie)
#        14    0.000    0.000    0.001    0.000 cookies.py:348(update)
#        27    0.000    0.000    0.001    0.000 cookies.py:37(__init__)
#         3    0.000    0.000    0.000    0.000 cookies.py:414(copy)
#         3    0.000    0.000    0.000    0.000 cookies.py:421(get_policy)
#         3    0.000    0.000    0.000    0.000 cookies.py:426(_copy_cookie_jar)
#        35    0.000    0.000    0.002    0.000 cookies.py:45(get_host)
#        35    0.000    0.000    0.002    0.000 cookies.py:48(get_origin_req_host)
#        15    0.000    0.000    0.001    0.000 cookies.py:508(cookiejar_from_dict)
#       106    0.000    0.000    0.002    0.000 cookies.py:51(get_full_url)
#        15    0.000    0.000    0.000    0.000 cookies.py:521(<listcomp>)
#        11    0.000    0.000    0.001    0.000 cookies.py:529(merge_cookies)
#        35    0.000    0.000    0.000    0.000 cookies.py:65(is_unverifiable)
#         1    0.000    0.000    0.000    0.000 cookies.py:68(has_header)
#         1    0.000    0.000    0.000    0.000 cookies.py:78(add_unredirected_header)
#         7    0.000    0.000    0.000    0.000 cookies.py:81(get_new_headers)
#        35    0.000    0.000    0.000    0.000 cookies.py:84(unverifiable)
#        35    0.000    0.000    0.002    0.000 cookies.py:88(origin_req_host)
#         1    0.000    0.000    0.000    0.000 copy.py:258(_reconstruct)
#        35    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         1    0.000    0.000    0.000    0.000 copyreg.py:90(__newobj__)
#       145    0.001    0.000    0.001    0.000 enum.py:283(__call__)
#       145    0.000    0.000    0.000    0.000 enum.py:562(__new__)
#        28    0.000    0.000    0.001    0.000 enum.py:827(__or__)
#         7    0.000    0.000    0.000    0.000 feedparser.py:101(push)
#        14    0.000    0.000    0.000    0.000 feedparser.py:122(pushlines)
#        14    0.000    0.000    0.000    0.000 feedparser.py:125(__iter__)
#       121    0.000    0.000    0.001    0.000 feedparser.py:128(__next__)
#         7    0.000    0.000    0.000    0.000 feedparser.py:139(__init__)
#         7    0.000    0.000    0.008    0.001 feedparser.py:173(feed)
#        14    0.000    0.000    0.008    0.001 feedparser.py:178(_call_parse)
#         7    0.000    0.000    0.001    0.000 feedparser.py:184(close)
#         7    0.000    0.000    0.000    0.000 feedparser.py:197(_new_message)
#         7    0.000    0.000    0.000    0.000 feedparser.py:210(_pop_message)
#        14    0.001    0.000    0.008    0.001 feedparser.py:218(_parsegen)
#         7    0.001    0.000    0.003    0.000 feedparser.py:471(_parse_headers)
#         7    0.000    0.000    0.000    0.000 feedparser.py:53(__init__)
#         7    0.000    0.000    0.000    0.000 feedparser.py:70(close)
#       121    0.001    0.000    0.001    0.000 feedparser.py:78(readline)
#        28    0.000    0.000    0.003    0.000 genericpath.py:16(exists)
#         7    0.000    0.000    0.001    0.000 genericpath.py:39(isdir)
#        15    0.000    0.000    0.000    0.000 hooks.py:17(default_hooks)
#        15    0.000    0.000    0.000    0.000 hooks.py:18(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 hooks.py:23(dispatch_hook)
#        14    0.000    0.000    0.000    0.000 idna.py:147(encode)
#        14    0.000    0.000    0.000    0.000 message.py:120(__init__)
#        14    0.000    0.000    0.000    0.000 message.py:181(is_multipart)
#         7    0.000    0.000    0.000    0.000 message.py:213(get_payload)
#        28    0.000    0.000    0.000    0.000 message.py:29(_splitparam)
#         7    0.000    0.000    0.000    0.000 message.py:303(set_payload)
#         7    0.000    0.000    0.002    0.000 message.py:451(items)
#         7    0.000    0.000    0.002    0.000 message.py:459(<listcomp>)
#        63    0.001    0.000    0.003    0.000 message.py:462(get)
#       100    0.000    0.000    0.000    0.000 message.py:479(set_raw)
#        40    0.001    0.000    0.003    0.000 message.py:497(get_all)
#        28    0.000    0.000    0.002    0.000 message.py:564(get_content_type)
#        21    0.000    0.000    0.001    0.000 message.py:588(get_content_maintype)
#         4    0.000    0.000    0.000    0.000 models.py:175(register_hook)
#         4    0.000    0.000    0.000    0.000 models.py:184(<genexpr>)
#         4    0.000    0.000    0.000    0.000 models.py:226(__init__)
#         7    0.000    0.000    0.000    0.000 models.py:291(__init__)
#         4    0.000    0.000    0.005    0.001 models.py:308(prepare)
#         3    0.000    0.000    0.001    0.000 models.py:329(copy)
#         4    0.000    0.000    0.000    0.000 models.py:340(prepare_method)
#         4    0.000    0.000    0.002    0.000 models.py:356(prepare_url)
#         4    0.000    0.000    0.001    0.000 models.py:442(prepare_headers)
#         4    0.000    0.000    0.000    0.000 models.py:453(prepare_body)
#         4    0.000    0.000    0.000    0.000 models.py:522(prepare_content_length)
#         4    0.000    0.000    0.000    0.000 models.py:535(prepare_auth)
#         7    0.000    0.000    0.002    0.000 models.py:557(prepare_cookies)
#         4    0.000    0.000    0.000    0.000 models.py:577(prepare_hooks)
#         7    0.000    0.000    0.001    0.000 models.py:597(__init__)
#         7    0.000    0.000    0.000    0.000 models.py:61(path_url)
#        10    0.000    0.000    0.000    0.000 models.py:708(is_redirect)
#         7    0.000    0.000    0.000    0.000 models.py:730(iter_content)
#        39    0.000    0.000    0.154    0.004 models.py:747(generate)
#        10    0.000    0.000    0.154    0.015 models.py:816(content)
#         4    0.000    0.000    0.000    0.000 models.py:82(_encode_params)
#         3    0.000    0.000    0.000    0.000 models.py:943(close)
#        21    0.000    0.000    0.001    0.000 ntpath.py:289(expanduser)
#        14    0.000    0.000    0.000    0.000 ntpath.py:34(_get_bothseps)
#      1780    0.008    0.000    0.025    0.000 os.py:670(__getitem__)
#      1734    0.004    0.000    0.004    0.000 os.py:693(__iter__)
#      1780    0.005    0.000    0.007    0.000 os.py:734(check_str)
#      1780    0.008    0.000    0.017    0.000 os.py:740(encodekey)
#       446    0.002    0.000    0.003    0.000 parse.py:110(_coerce_args)
#         4    0.000    0.000    0.000    0.000 parse.py:147(username)
#        62    0.001    0.000    0.002    0.000 parse.py:155(hostname)
#         4    0.000    0.000    0.000    0.000 parse.py:183(_userinfo)
#        62    0.000    0.000    0.001    0.000 parse.py:195(_hostinfo)
#        10    0.000    0.000    0.000    0.000 parse.py:330(geturl)
#       188    0.002    0.000    0.008    0.000 parse.py:366(urlparse)
#       230    0.002    0.000    0.004    0.000 parse.py:417(urlsplit)
#        14    0.000    0.000    0.001    0.000 parse.py:474(urlunparse)
#        14    0.000    0.000    0.000    0.000 parse.py:485(urlunsplit)
#         4    0.000    0.000    0.000    0.000 parse.py:624(unquote)
#        85    0.001    0.000    0.003    0.000 parse.py:787(quote)
#        85    0.001    0.000    0.002    0.000 parse.py:858(quote_from_bytes)
#         4    0.000    0.000    0.000    0.000 parse.py:880(urlencode)
#       446    0.001    0.000    0.001    0.000 parse.py:99(_noop)
#         7    0.000    0.000    0.000    0.000 parser.py:17(__init__)
#         7    0.000    0.000    0.010    0.001 parser.py:41(parse)
#         7    0.000    0.000    0.010    0.001 parser.py:59(parsestr)
#         8    0.000    0.000    0.000    0.000 poolmanager.py:165(__init__)
#         7    0.000    0.000    0.019    0.003 poolmanager.py:168(<lambda>)
#         7    0.000    0.000    0.006    0.001 poolmanager.py:183(_new_pool)
#         8    0.000    0.000    0.020    0.002 poolmanager.py:210(clear)
#         7    0.000    0.000    0.007    0.001 poolmanager.py:219(connection_from_host)
#         7    0.000    0.000    0.006    0.001 poolmanager.py:242(connection_from_context)
#         7    0.000    0.000    0.006    0.001 poolmanager.py:255(connection_from_pool_key)
#         7    0.000    0.000    0.009    0.001 poolmanager.py:279(connection_from_url)
#         7    0.000    0.000    0.000    0.000 poolmanager.py:295(_merge_pool_kwargs)
#         7    0.000    0.000    0.000    0.000 poolmanager.py:74(_default_key_normalizer)
#         7    0.000    0.000    0.000    0.000 queue.py:11(_init)
#        77    0.001    0.000    0.004    0.000 queue.py:121(put)
#       161    0.001    0.000    0.001    0.000 queue.py:14(_qsize)
#        84    0.001    0.000    0.003    0.000 queue.py:153(get)
#        77    0.000    0.000    0.000    0.000 queue.py:17(_put)
#        77    0.000    0.000    0.000    0.000 queue.py:20(_get)
#         7    0.000    0.000    0.000    0.000 queue.py:33(__init__)
#        17    0.006    0.000    0.043    0.003 request.py:2490(getproxies_environment)
#         7    0.000    0.000    0.000    0.000 request.py:2653(getproxies_registry)
#         7    0.000    0.000    0.018    0.003 request.py:2698(getproxies)
#        15    0.000    0.000    0.000    0.000 request.py:41(__init__)
#         7    0.000    0.000    0.000    0.000 request.py:90(set_file_position)
#         5    0.000    0.000    0.000    0.000 response.py:142(_get_decoder)
#         7    0.000    0.000    0.001    0.000 response.py:193(__init__)
#        14    0.000    0.000    0.000    0.000 response.py:249(<genexpr>)
#        10    0.000    0.000    0.000    0.000 response.py:273(release_conn)
#         7    0.000    0.000    0.000    0.000 response.py:315(_init_length)
#         4    0.000    0.000    0.000    0.000 response.py:341(<listcomp>)
#         7    0.000    0.000    0.000    0.000 response.py:367(_init_decoder)
#         7    0.000    0.000    0.001    0.000 response.py:38(assert_header_parsing)
#        49    0.000    0.000    0.004    0.000 response.py:390(_decode)
#         3    0.000    0.000    0.000    0.000 response.py:412(_flush_decoder)
#        14    0.000    0.000    0.001    0.000 response.py:423(_error_catcher)
#         4    0.000    0.000    0.001    0.000 response.py:480(read)
#        39    0.000    0.000    0.154    0.004 response.py:554(stream)
#         7    0.000    0.000    0.004    0.001 response.py:580(from_httplib)
#         7    0.000    0.000    0.000    0.000 response.py:616(getheader)
#         7    0.000    0.000    0.000    0.000 response.py:634(closed)
#         6    0.000    0.000    0.000    0.000 response.py:679(supports_chunked_reads)
#        49    0.000    0.000    0.068    0.001 response.py:688(_update_chunk_length)
#         8    0.000    0.000    0.000    0.000 response.py:7(is_fp_closed)
#        46    0.000    0.000    0.079    0.002 response.py:702(_handle_chunk)
#        33    0.001    0.000    0.152    0.005 response.py:724(read_chunked)
#         5    0.000    0.000    0.000    0.000 response.py:73(__init__)
#         3    0.000    0.000    0.000    0.000 response.py:74(is_response_to_head)
#         3    0.000    0.000    0.000    0.000 response.py:77(__getattr__)
#        51    0.001    0.000    0.003    0.000 response.py:80(decompress)
#         8    0.000    0.000    0.000    0.000 retry.py:162(__init__)
#         8    0.000    0.000    0.000    0.000 retry.py:197(<listcomp>)
#         7    0.000    0.000    0.000    0.000 retry.py:327(_is_method_retryable)
#         7    0.000    0.000    0.000    0.000 retry.py:336(is_retry)
#      10/7    0.000    0.000    0.887    0.127 sessions.py:144(resolve_redirects)
#         3    0.000    0.000    0.001    0.000 sessions.py:254(rebuild_auth)
#         3    0.000    0.000    0.024    0.008 sessions.py:273(rebuild_proxies)
#         3    0.000    0.000    0.000    0.000 sessions.py:314(rebuild_method)
#         4    0.000    0.000    0.001    0.000 sessions.py:362(__init__)
#         4    0.000    0.000    0.000    0.000 sessions.py:417(__enter__)
#         4    0.000    0.000    0.020    0.005 sessions.py:420(__exit__)
#         4    0.000    0.000    0.009    0.002 sessions.py:423(prepare_request)
#         4    0.000    0.000    2.005    0.501 sessions.py:463(request)
#        28    0.000    0.000    0.002    0.000 sessions.py:50(merge_setting)
#       7/4    0.000    0.000    1.972    0.493 sessions.py:614(send)
#         4    0.000    0.000    0.887    0.222 sessions.py:665(<listcomp>)
#         4    0.000    0.000    0.024    0.006 sessions.py:689(merge_environment_settings)
#         7    0.000    0.000    0.000    0.000 sessions.py:718(get_adapter)
#         4    0.000    0.000    0.020    0.005 sessions.py:732(close)
#         8    0.000    0.000    0.000    0.000 sessions.py:737(mount)
#        12    0.000    0.000    0.000    0.000 sessions.py:74(<listcomp>)
#         8    0.000    0.000    0.000    0.000 sessions.py:743(<listcomp>)
#         4    0.000    0.000    0.000    0.000 sessions.py:81(merge_hooks)
#        10    0.000    0.000    0.000    0.000 sessions.py:98(get_redirect_target)
#         8    0.000    0.000    0.000    0.000 six.py:614(itervalues)
#        25    0.000    0.000    0.000    0.000 six.py:939(ensure_str)
#        43    0.000    0.000    0.000    0.000 six.py:959(ensure_text)
#        14    0.001    0.000    0.001    0.000 socket.py:219(__init__)
#         7    0.000    0.000    0.000    0.000 socket.py:301(makefile)
#         7    0.000    0.000    0.000    0.000 socket.py:486(_decref_socketios)
#         7    0.000    0.000    0.001    0.000 socket.py:492(_real_close)
#         7    0.000    0.000    0.002    0.000 socket.py:496(close)
#         7    0.000    0.000    0.000    0.000 socket.py:502(detach)
#         7    0.000    0.000    0.000    0.000 socket.py:512(family)
#         7    0.000    0.000    0.000    0.000 socket.py:518(type)
#         7    0.000    0.000    0.000    0.000 socket.py:643(__init__)
#        57    0.001    0.000    0.917    0.016 socket.py:655(readinto)
#        64    0.000    0.000    0.000    0.000 socket.py:694(readable)
#         7    0.000    0.000    0.000    0.000 socket.py:732(close)
#         7    0.000    0.000    0.007    0.001 socket.py:901(getaddrinfo)
#        68    0.000    0.000    0.001    0.000 socket.py:97(_intenum_converter)
#       135    0.000    0.000    0.000    0.000 ssl.py:1078(_checkClosed)
#        14    0.000    0.000    0.000    0.000 ssl.py:1082(_check_connected)
#        57    0.000    0.000    0.916    0.016 ssl.py:1090(read)
#         7    0.000    0.000    0.001    0.000 ssl.py:1120(getpeercert)
#         7    0.000    0.000    0.001    0.000 ssl.py:1166(send)
#         7    0.000    0.000    0.001    0.000 ssl.py:1193(sendall)
#        57    0.001    0.000    0.916    0.016 ssl.py:1230(recv_into)
#         7    0.001    0.000    0.001    0.000 ssl.py:1298(_real_close)
#         7    0.000    0.000    0.457    0.065 ssl.py:1302(do_handshake)
#        96    0.001    0.000    0.001    0.000 ssl.py:275(_dnsname_match)
#         7    0.000    0.000    0.000    0.000 ssl.py:324(_inet_paton)
#         7    0.001    0.000    0.002    0.000 ssl.py:371(match_hostname)
#         7    0.000    0.000    0.002    0.000 ssl.py:482(__new__)
#         7    0.000    0.000    0.000    0.000 ssl.py:486(_encode_hostname)
#         7    0.000    0.000    0.459    0.066 ssl.py:494(wrap_socket)
#         7    0.000    0.000    0.000    0.000 ssl.py:596(options)
#         7    0.000    0.000    0.000    0.000 ssl.py:600(options)
#        14    0.000    0.000    0.000    0.000 ssl.py:710(verify_mode)
#        14    0.000    0.000    0.000    0.000 ssl.py:718(verify_mode)
#         7    0.000    0.000    0.459    0.066 ssl.py:983(_create)
#        14    0.000    0.000    0.000    0.000 ssl_.py:185(resolve_cert_reqs)
#         7    0.000    0.000    0.000    0.000 ssl_.py:208(resolve_ssl_version)
#         7    0.000    0.000    0.004    0.001 ssl_.py:224(create_urllib3_context)
#         7    0.000    0.000    0.610    0.087 ssl_.py:308(ssl_wrap_socket)
#         7    0.000    0.000    0.000    0.000 ssl_.py:402(is_ipaddress)
#        29    0.000    0.000    0.004    0.000 structures.py:42(__init__)
#       151    0.001    0.000    0.001    0.000 structures.py:48(__setitem__)
#       222    0.001    0.000    0.001    0.000 structures.py:53(__getitem__)
#        26    0.000    0.000    0.000    0.000 structures.py:59(__iter__)
#       132    0.000    0.000    0.000    0.000 structures.py:60(<genexpr>)
#        12    0.000    0.000    0.000    0.000 structures.py:62(__len__)
#         3    0.000    0.000    0.000    0.000 structures.py:82(copy)
#        21    0.000    0.000    0.000    0.000 threading.py:222(__init__)
#       161    0.000    0.000    0.001    0.000 threading.py:246(__enter__)
#       161    0.001    0.000    0.001    0.000 threading.py:249(__exit__)
#       154    0.000    0.000    0.001    0.000 threading.py:261(_is_owned)
#       154    0.001    0.000    0.002    0.000 threading.py:341(notify)
#        30    0.000    0.000    0.000    0.000 threading.py:81(RLock)
#        84    0.000    0.000    0.000    0.000 timeout.py:112(_validate_timeout)
#         7    0.000    0.000    0.000    0.000 timeout.py:158(from_float)
#        14    0.000    0.000    0.000    0.000 timeout.py:174(clone)
#         7    0.000    0.000    0.000    0.000 timeout.py:188(start_connect)
#        21    0.000    0.000    0.000    0.000 timeout.py:213(connect_timeout)
#         7    0.000    0.000    0.000    0.000 timeout.py:231(read_timeout)
#        28    0.000    0.000    0.000    0.000 timeout.py:95(__init__)
#        21    0.000    0.000    0.001    0.000 url.py:210(_encode_invalid_chars)
#         7    0.000    0.000    0.000    0.000 url.py:244(_remove_path_dot_segments)
#        18    0.000    0.000    0.002    0.000 url.py:274(_normalize_host)
#        18    0.000    0.000    0.001    0.000 url.py:297(<listcomp>)
#        42    0.000    0.000    0.001    0.000 url.py:302(_idna_encode)
#        42    0.000    0.000    0.001    0.000 url.py:303(<listcomp>)
#         7    0.000    0.000    0.000    0.000 url.py:320(_encode_target)
#        11    0.001    0.000    0.003    0.000 url.py:330(parse_url)
#        66    0.000    0.000    0.000    0.000 url.py:411(ensure_type)
#        11    0.000    0.000    0.000    0.000 url.py:91(__new__)
#         7    0.000    0.000    0.003    0.000 utils.py:169(get_netrc_auth)
#         7    0.000    0.000    0.001    0.000 utils.py:228(extract_zipped_paths)
#        28    0.000    0.000    0.001    0.000 utils.py:287(to_key_val_list)
#         7    0.000    0.000    0.000    0.000 utils.py:455(_parse_content_type_header)
#        10    0.000    0.000    0.001    0.000 utils.py:48(proxy_bypass_registry)
#         7    0.000    0.000    0.000    0.000 utils.py:480(get_encoding_from_headers)
#       192    0.001    0.000    0.001    0.000 utils.py:51(_has_surrogates)
#         7    0.000    0.000    0.000    0.000 utils.py:519(iter_slices)
#         7    0.000    0.000    0.000    0.000 utils.py:570(unquote_unreserved)
#         7    0.000    0.000    0.000    0.000 utils.py:594(requote_uri)
#        20    0.000    0.000    0.000    0.000 utils.py:677(set_environ)
#        10    0.000    0.000    0.028    0.003 utils.py:699(should_bypass_proxies)
#        10    0.000    0.000    0.001    0.000 utils.py:707(<lambda>)
#         7    0.000    0.000    0.039    0.006 utils.py:760(get_environ_proxies)
#        14    0.000    0.000    0.002    0.000 utils.py:772(select_proxy)
#         4    0.000    0.000    0.000    0.000 utils.py:798(default_user_agent)
#         4    0.000    0.000    0.000    0.000 utils.py:807(default_headers)
#        10    0.000    0.000    0.026    0.003 utils.py:87(proxy_bypass)
#         4    0.000    0.000    0.000    0.000 utils.py:911(get_auth_from_url)
#        16    0.000    0.000    0.000    0.000 utils.py:932(check_header_validity)
#       221    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x00007FFD1862B810}
#       121    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         7    0.006    0.001    0.006    0.001 {built-in method _socket.getaddrinfo}
#         7    0.000    0.000    0.000    0.000 {built-in method _socket.inet_aton}
#         7    0.000    0.000    0.000    0.000 {built-in method _socket.inet_pton}
#         7    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         7    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    2.027    2.027 {built-in method builtins.exec}
#       358    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#       217    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#      3471    0.005    0.000    0.006    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#   707/699    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#        37    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#       183    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        21    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#        35    0.003    0.000    0.003    0.000 {built-in method nt.stat}
#         7    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        14    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#        34    0.000    0.000    0.000    0.000 {built-in method time.time}
#         7    0.000    0.000    0.000    0.000 {built-in method today}
#        17    0.000    0.000    0.000    0.000 {built-in method winreg.OpenKey}
#        27    0.000    0.000    0.000    0.000 {built-in method winreg.QueryValueEx}
#         5    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         7    0.000    0.000    0.000    0.000 {function HTTPResponse.flush at 0x0000016B775D6EE0}
#        18    0.000    0.000    0.000    0.000 {function SocketIO.close at 0x0000016B76B39AF0}
#         7    0.001    0.000    0.001    0.000 {function socket.close at 0x0000016B76B390D0}
#         7    0.000    0.000    0.000    0.000 {function socket.detach at 0x0000016B76B39160}
#         7    0.000    0.000    0.000    0.000 {method 'Close' of 'PyHKEY' objects}
#       161    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       161    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        57    0.000    0.000    0.000    0.000 {method '_checkClosed' of '_io._IOBase' objects}
#        57    0.000    0.000    0.000    0.000 {method '_checkReadable' of '_io._IOBase' objects}
#         7    0.000    0.000    0.000    0.000 {method '_wrap_socket' of '_ssl._SSLContext' objects}
#        69    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       154    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        77    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       956    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'cast' of 'memoryview' objects}
#         8    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         7    0.306    0.044    0.306    0.044 {method 'connect' of '_socket.socket' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'collections.OrderedDict' objects}
#        56    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'count' of 'bytes' objects}
#       124    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'decode' of 'bytearray' objects}
#       134    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        48    0.003    0.000    0.003    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         7    0.457    0.065    0.457    0.065 {method 'do_handshake' of '_ssl._SSLSocket' objects}
#   525/518    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#       102    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'extend' of 'collections.deque' objects}
#        26    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 {method 'fileno' of '_socket.socket' objects}
#       254    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BufferedReader' objects}
#         3    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Decompress' objects}
#        21    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method 'fullmatch' of 're.Pattern' objects}
#       740    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         7    0.001    0.000    0.001    0.000 {method 'getpeercert' of '_ssl._SSLSocket' objects}
#         7    0.000    0.000    0.000    0.000 {method 'getpeername' of '_socket.socket' objects}
#         7    0.000    0.000    0.000    0.000 {method 'getsockopt' of '_socket.socket' objects}
#        21    0.000    0.000    0.000    0.000 {method 'gettimeout' of '_socket.socket' objects}
#        72    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#        43    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        19    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#        68    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        75    0.001    0.000    0.154    0.002 {method 'join' of 'bytes' objects}
#       239    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        55    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         7    0.151    0.022    0.151    0.022 {method 'load_verify_locations' of '_ssl._SSLContext' objects}
#      3853    0.005    0.000    0.005    0.000 {method 'lower' of 'str' objects}
#       116    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       209    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#       601    0.001    0.000    0.001    0.000 {method 'partition' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#        77    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#        84    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#       107    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        90    0.000    0.000    0.078    0.001 {method 'read' of '_io.BufferedReader' objects}
#        14    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#        57    0.915    0.016    0.915    0.016 {method 'read' of '_ssl._SSLSocket' objects}
#         4    0.000    0.000    0.000    0.000 {method 'readinto' of '_io.BufferedReader' objects}
#       164    0.001    0.000    0.840    0.005 {method 'readline' of '_io.BufferedReader' objects}
#        14    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        69    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        66    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        85    0.000    0.000    0.000    0.000 {method 'rstrip' of 'bytes' objects}
#       121    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       222    0.001    0.000    0.001    0.000 {method 'search' of 're.Pattern' objects}
#        28    0.000    0.000    0.000    0.000 {method 'seek' of '_io.StringIO' objects}
#         7    0.001    0.000    0.001    0.000 {method 'set_ciphers' of '_ssl._SSLContext' objects}
#       100    0.000    0.000    0.000    0.000 {method 'setdefault' of 'collections.OrderedDict' objects}
#        32    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'setsockopt' of '_socket.socket' objects}
#        28    0.000    0.000    0.000    0.000 {method 'settimeout' of '_socket.socket' objects}
#         7    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        61    0.000    0.000    0.000    0.000 {method 'split' of 'bytes' objects}
#       221    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       474    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#       773    0.001    0.000    0.001    0.000 {method 'strip' of 'str' objects}
#       161    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#        14    0.000    0.000    0.000    0.000 {method 'subn' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'tobytes' of 'memoryview' objects}
#        43    0.000    0.000    0.000    0.000 {method 'toordinal' of 'datetime.date' objects}
#        14    0.000    0.000    0.000    0.000 {method 'truncate' of '_io.StringIO' objects}
#         8    0.000    0.000    0.000    0.000 {method 'update' of 'collections.OrderedDict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      1831    0.002    0.000    0.002    0.000 {method 'upper' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         7    0.001    0.000    0.001    0.000 {method 'write' of '_ssl._SSLSocket' objects}

# %% [markdown]
# <h1>Справочник по модулю</h1>
#
# Модули profile и cProfile обеспечивают следующие функции:
#
# <b>profile.run(command, filename=None, sort=-1)</b>
#
# Эта функция принимает один аргумент, который может быть передан функции exec(), и дополнительное имя файла. Во всех случаях эта подпрограмма выполняется:

# %%
exec(command, __main__.__dict__, __main__.__dict__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b0a7753eae10> in <module>
# ----> 1 exec(command, __main__.__dict__, __main__.__dict__)
#
# NameError: name 'command' is not defined

# %% [markdown]
# Функция собирает статистику профилирования. Если имя файла не указано, то эта функция автоматически создает Stats сущность и печатает простой профильный отчет. Если вид, значение определены, то exec() передает Stats сущность, чтобы управлять, сортировкой результата.

# %% [markdown]
# <b>profile.runctx(command, globals, locals, filename=None, sort=-1)</b>
#
# Эта функция похожа на run(), с добавленными аргументами, чтобы предоставить глобальные и локальные словари для command строк.

# %%
exec(command, globals, locals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74f7221ad9fd> in <module>
# ----> 1 exec(command, globals, locals)
#
# NameError: name 'command' is not defined

# %% [markdown]
# Эта подпрограмма выполняется и собирает профильную статистику как в функции run() выше.

# %% [markdown]
# <b>class profile.Profile(timer=None, timeunit=0.0, subcalls=True, builtins=True)</b>
#
# Этот класс обычно является используемый только в том случае, если требуется более точный контроль за профилированием, чем то, что обеспечивает функция cProfile.run().
#
# Пользовательский таймер может быть предоставлен для измерения, сколько времени занимает код для запуска через аргумент timer. Это должна быть функция, которая возвращает одно число представляя текущее время. Если число является целым числом, timeunit определяет множитель, который указывает продолжительность каждой единицы времени. Например, если таймер возвращает время, измеренное в тысячах секунд, единица времени будет .001.
#
# Непосредственно использование класса Profile позволяет форматировать результаты профиля, не в письме к данные о профиле файлу:

# %% [markdown]
# В версии Python 3.8  добавлена поддержка следующих функций:
#
# enable()
# Начать сбор данных профилирования. Только в cProfile.
#
# disable()
# Прекратить сбор данных профилирования. Только в cProfile.
#
# create_stats()
# Прекратить сбор данных профилирования и записать результаты в качестве текущего профиля.
#
# print_stats(sort=-1)
# Создайть объект Stats на основе текущего профиля и распечатать результаты для stdout.
#
# dump_stats(filename)
# Записать результаты текущего профиля в filename.
#
# run(cmd)
# Выполнить профилирование cmd через exec().
#
# runctx(cmd, globals, locals)
# Выполнить профилирование cmd через exec() с помощью указанной глобальной и локальной сред.
#
# runcall(func, *args, **kwargs)
# Профиль func(*args, **kwargs)
#
# Следует отметить, что профилирование будет работать только в том случае, если вызываемая команда/функция действительно возвращает что-либо. Если интерпретатор завершается (например, посредством вызова sys.exit() во время выполнения вызываемой команды/функции), результаты профилирования не будут напечатаны.

# %% [markdown]
# <h1>Использование пользовательского таймера</h1>
#
# Если необходимо изменить способ определения текущего времени (например, принудительно использовать время настенных часов или истекшее время процесса), передайте нужную функцию синхронизации конструктору класса Profile:
#
# <b>pr = profile.Profile(your_time_func)</b>
#
# Полученный профилировщик вызовет your_time_func. В зависимости от того, используется ли profile.Profile или cProfile.Profile, возвращает значение your_time_func будет интерпретироваться по-разному:
#
# <b>profile.Profile</b>
#
# your_time_func должен возвращает единственное число или список чисел, сумма которых - текущее время (как какой os.times() возвращает). Если функция возвращает один временной номер или список номеров возвращенный имеет длину 2, то вы получите особенно быструю версию подпрограммы отправки.
#
# Обратите внимание на необходимость калибровки класса профилировщика для выбранной функции таймера (см. Ограничения). Для большинства машин, таймера, что возвращает одинокий целочисленный значение обеспечит лучшие результаты с точки зрения низкого наверху во время профилирования. (os.times() - pretty плохо как он возвращает кортеж плавающей запятой значения). Если вы хотите заменить лучший таймер самым чистым способом, выведите класс и выполните аппаратную проводку метода замены, который лучше всего обрабатывает ваш вызов таймера, вместе с соответствующей калибровочной константой.
#
# <b>cProfile.Profile</b>
#
# your_time_func должен возвращает один номер. Если это целые числа возвращает, вы можете также призвать конструктора класса со вторым аргументом, определяющим реальную продолжительность одной единицы времени. Например, если your_integer_time_func возвращает раз измерено в тысячах секунд, вы построите Profile сущность следующим образом:
#
# <b>pr = cProfile.Profile(your_integer_time_func, 0.001)</b>
#
# Поскольку класс cProfile.Profile не может быть откалиброван, пользовательские функции таймера должны быть используемый с осторожностью и должны быть как можно быстрее. Для лучших результатов с пользовательским таймером это могло бы быть необходимо для твердого-код это в источнике C внутреннего модуля _lsprof.
